# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

data = pd.read_csv('./Data/hackathon.csv')

data.head()
# Out:
#                                      id  age  income_level  debt_level  \
# 0  d5a4ec26-3615-45a5-868d-7359fc0302f0   46      89484.49    10909.28
# 1  b59d6c82-b9a0-4cf4-ae57-7edff2451250   80      75860.61     4144.29
# 2  3ea8ca83-a07e-46de-a718-9c9c097e5c07   52       9589.85     1453.86
# 3  77e32f86-8fba-4f46-ab0d-aebe45e54c6b   52       8848.68    31933.44
# 4  724e2fed-f0ae-4e93-a681-c772c4b9415c   48      13823.01     7271.22
#
#      region loan_access data_accuracy misidentified_vulnerability  \
# 0  Suburban        True      Accurate                       False
# 1     Rural        True      Accurate                       False
# 2  Suburban       False      Outdated                       False
# 3     Urban        True      Outdated                       False
# 4     Urban       False      Outdated                       False
#
#   access_to_bank_account access_to_credit_card  ... access_to_counselling  \
# ...

# %%
def load_data(filename: str):
    """
    :param filename: name of the file to load, must be in the 'Data' folder
    :return:
    """
    financial_vul = pd.read_csv('./Data/'+filename)
    return financial_vul

data = load_data('hackathon.csv')
# Out:
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
data.head()
# Out:
#                                      id  age  income_level  debt_level  \
# 0  d5a4ec26-3615-45a5-868d-7359fc0302f0   46      89484.49    10909.28
# 1  b59d6c82-b9a0-4cf4-ae57-7edff2451250   80      75860.61     4144.29
# 2  3ea8ca83-a07e-46de-a718-9c9c097e5c07   52       9589.85     1453.86
# 3  77e32f86-8fba-4f46-ab0d-aebe45e54c6b   52       8848.68    31933.44
# 4  724e2fed-f0ae-4e93-a681-c772c4b9415c   48      13823.01     7271.22
#
#      region loan_access data_accuracy misidentified_vulnerability  \
# 0  Suburban        True      Accurate                       False
# 1     Rural        True      Accurate                       False
# 2  Suburban       False      Outdated                       False
# 3     Urban        True      Outdated                       False
# 4     Urban       False      Outdated                       False
#
#   access_to_bank_account access_to_credit_card  ... access_to_counselling  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           4000 non-null   object
#  1   age                          4000 non-null   int64
#  2   income_level                 4000 non-null   float64
#  3   debt_level                   4000 non-null   float64
#  4   region                       4000 non-null   object
#  5   loan_access                  2000 non-null   object
#  6   data_accuracy                1000 non-null   object
#  7   misidentified_vulnerability  1000 non-null   object
#  8   access_to_bank_account       2000 non-null   object
#  9   access_to_credit_card        2000 non-null   object
#  10  access_to_insurance          1000 non-null   object
#  11  financial_literacy_score     3000 non-null   float64
#  12  vulnerable                   1000 non-null   object
# ...

# %%
# clean data, convert string fields to numric, remove columns that are not needed, remove columns that could lead to collinearity
columns_to_drop = ['id', 'loan_history', 'misidentified_vulnerability', 'vulnerable'
    
]

# %%
trainX = data.drop(columns=['vulnerable'])

# %%
data['vulnerable'].value_counts()
# need to normalise the data to have equal numbers of TRUE and FALSE
# Out:
# vulnerable
# True     647
# False    353
# Name: count, dtype: int64

# %%
X = trainX
y= data.vulnerable

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

clf = make_pipeline(StandardScaler(),LinearSVC(dual="auto", random_state=0, tol=1e-5))
models,predictions = clf.fit(X_train,y_train,)

print(models)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lf/115jwn9d76j8jxcxpfj6nvsh0000gq/T/ipykernel_38902/711773877.py in ?()
# ----> 7 X = trainX
#       8 y= data.vulnerable
#       9
#      10 X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)
#
# ~/withack/.venv/lib/python3.9/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~/withack/.venv/lib/python3.9/site-packages/sklearn/pipeline.py in ?(self, X, y, **params)
#     465         self : object
#     466             Pipeline with fitted steps.
#     467         """
# ...
