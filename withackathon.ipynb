# %%
# import pandas as pd
from src.model import load_data
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.svm import LinearSVC

data = load_data("hackathon.csv")

# %%
data = data.query(
    "vulnerable.notnull()"
)  # remove columns where the target variable is not null
data.head()
# Out:
#                                         id  age  income_level  debt_level  \
# 1000  167e572d-2e8f-4acd-998e-f23c2638c7d3   49      22915.70    35145.79
# 1001  b75dd204-4790-4a22-b67f-41d5a43f35e8   67      48055.16    33226.69
# 1002  fe9b575b-80ea-4970-8bd0-19539d8fdac6   21      77593.44    34633.12
# 1003  b8b1cac4-65e2-4e35-a8f2-da360a2be376   81      46981.69    12117.45
# 1004  079fd96b-5aac-4332-85aa-882d7fe9e0d7   71      66805.21     6379.73
#
#         region loan_access data_accuracy misidentified_vulnerability  \
# 1000     Urban       False           NaN                         NaN
# 1001     Rural        True           NaN                         NaN
# 1002  Suburban        True           NaN                         NaN
# 1003     Urban        True           NaN                         NaN
# 1004     Urban        True           NaN                         NaN
#
#      access_to_bank_account access_to_credit_card  ... access_to_counselling  \
# 1000                   True                 False  ...                   NaN
# 1001                   True                 False  ...                   NaN
# 1002                  False                  True  ...                   NaN
# 1003                   True                 False  ...                   NaN
# 1004                   True                 False  ...                   NaN
#
#       financial_shocks_annual marital_status  no_dependents creditworthy  \
# 1000                      NaN            NaN            NaN          NaN
# 1001                      NaN            NaN            NaN          NaN
# 1002                      NaN            NaN            NaN          NaN
# 1003                      NaN            NaN            NaN          NaN
# 1004                      NaN            NaN            NaN          NaN
#
#       monthly_expenses access_financial_education  has_emergency_savings  \
# 1000               NaN                        NaN                    NaN
# 1001               NaN                        NaN                    NaN
# 1002               NaN                        NaN                    NaN
# 1003               NaN                        NaN                    NaN
# 1004               NaN                        NaN                    NaN
#
#       financially_resilient  employment_status
# 1000                    NaN         Unemployed
# 1001                    NaN      Self-employed
# 1002                    NaN            Retired
# 1003                    NaN         Unemployed
# 1004                    NaN         Unemployed
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1000 to 1999
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1000 non-null   object
#  1   age                          1000 non-null   int64
#  2   income_level                 1000 non-null   float64
#  3   debt_level                   1000 non-null   float64
#  4   region                       1000 non-null   object
#  5   loan_access                  1000 non-null   object
#  6   data_accuracy                0 non-null      object
#  7   misidentified_vulnerability  0 non-null      object
#  8   access_to_bank_account       1000 non-null   object
#  9   access_to_credit_card        1000 non-null   object
#  10  access_to_insurance          1000 non-null   object
#  11  financial_literacy_score     1000 non-null   float64
#  12  vulnerable                   1000 non-null   object
#  13  savings_amount               1000 non-null   float64
#  14  income_stability             1000 non-null   object
#  15  credit_score                 1000 non-null   float64
#  16  loan_history                 1000 non-null   object
#  17  late_payments_yearly         1000 non-null   float64
#  18  bankruptcies_filed           1000 non-null   float64
#  19  credit_utilisation_ratio     1000 non-null   float64
#  20  access_to_counselling        0 non-null      object
#  21  financial_shocks_annual      0 non-null      object
#  22  marital_status               0 non-null      object
#  23  no_dependents                0 non-null      float64
#  24  creditworthy                 0 non-null      object
#  25  monthly_expenses             0 non-null      float64
#  26  access_financial_education   0 non-null      object
#  27  has_emergency_savings        0 non-null      object
#  28  financially_resilient        0 non-null      object
#  29  employment_status            1000 non-null   object
# dtypes: float64(10), int64(1), object(19)
# memory usage: 242.2+ KB

# %%
data = data.dropna(axis="columns", how="all")

# %%
data.head()
# Out:
#                                         id  age  income_level  debt_level  \
# 1000  167e572d-2e8f-4acd-998e-f23c2638c7d3   49      22915.70    35145.79
# 1001  b75dd204-4790-4a22-b67f-41d5a43f35e8   67      48055.16    33226.69
# 1002  fe9b575b-80ea-4970-8bd0-19539d8fdac6   21      77593.44    34633.12
# 1003  b8b1cac4-65e2-4e35-a8f2-da360a2be376   81      46981.69    12117.45
# 1004  079fd96b-5aac-4332-85aa-882d7fe9e0d7   71      66805.21     6379.73
#
#         region loan_access access_to_bank_account access_to_credit_card  \
# 1000     Urban       False                   True                 False
# 1001     Rural        True                   True                 False
# 1002  Suburban        True                  False                  True
# 1003     Urban        True                   True                 False
# 1004     Urban        True                   True                 False
#
#      access_to_insurance  financial_literacy_score vulnerable  savings_amount  \
# 1000                True                      73.0       True       107928.28
# 1001                True                      10.0      False        59130.56
# 1002                True                      59.0       True       124376.24
# 1003               False                      40.0      False        83136.27
# 1004                True                      12.0      False       116517.84
#
#      income_stability  credit_score loan_history  late_payments_yearly  \
# 1000         Unstable         519.0         True                   2.0
# 1001           Stable         335.0        False                   2.0
# 1002           Stable         480.0         True                   6.0
# 1003           Stable         495.0         True                   9.0
# 1004           Stable         797.0         True                   1.0
#
#       bankruptcies_filed  credit_utilisation_ratio employment_status
# 1000                 0.0                      0.77        Unemployed
# 1001                 0.0                      0.32     Self-employed
# 1002                 0.0                      0.88           Retired
# 1003                 0.0                      0.36        Unemployed
# 1004                 0.0                      0.84        Unemployed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1000 to 1999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1000 non-null   object
#  1   age                       1000 non-null   int64
#  2   income_level              1000 non-null   float64
#  3   debt_level                1000 non-null   float64
#  4   region                    1000 non-null   float64
#  5   loan_access               1000 non-null   int64
#  6   access_to_bank_account    1000 non-null   int64
#  7   access_to_credit_card     1000 non-null   int64
#  8   access_to_insurance       1000 non-null   object
#  9   financial_literacy_score  1000 non-null   float64
#  10  vulnerable                1000 non-null   int64
#  11  savings_amount            1000 non-null   float64
#  12  income_stability          1000 non-null   int64
#  13  credit_score              1000 non-null   float64
#  14  loan_history              1000 non-null   int64
#  15  late_payments_yearly      1000 non-null   float64
#  16  bankruptcies_filed        1000 non-null   float64
#  17  credit_utilisation_ratio  1000 non-null   float64
#  18  employment_status         1000 non-null   float64
# dtypes: float64(10), int64(7), object(2)
# memory usage: 156.2+ KB

# %%
print("access_to insurance counts:", data["access_to_insurance"].value_counts())
print("income stability:", data["income_stability"].value_counts())
# Out:
# access_to insurance counts: access_to_insurance
# True     523
# False    477
# Name: count, dtype: int64
# income stability: income_stability
# Stable      742
# Unstable    258
# Name: count, dtype: int64

# %%
# convert TRUE/FALSE dt to numeric
boolean_dt = [
    "loan_access",
    "access_to_bank_account",
    "access_to_credit_card",
    "vulnerable",
    "loan_history",
]

data[boolean_dt] = data[boolean_dt].astype(int)

# options are stable/unstable for "income_stability" change to 1 or 0
data["income_stability"] = data["income_stability"].replace(
    {"Stable": 1, "Unstable": 0}
)
# Out:
# C:\Users\leahs\AppData\Local\Temp\ipykernel_8540\676891444.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['income_stability'] = data['income_stability'].replace({'Stable': 1, 'Unstable': 0})

# %%
# encode categorical data
categorical_data = ["region", "employment_status"]

enc = OrdinalEncoder()  # noqa: F821
enc.fit(data[categorical_data])
data[categorical_data] = enc.transform(data[categorical_data])

# %%
print("income stability:", data["income_stability"].value_counts())
print("region:", data["region"].value_counts())
print("employment_status:", data["employment_status"].value_counts())
# Out:
# income stability: income_stability
# 1    742
# 0    258
# Name: count, dtype: int64
# region: region
# Urban       352
# Rural       325
# Suburban    323
# Name: count, dtype: int64
# employment_status: employment_status
# Self-employed    290
# Employed         257
# Retired          234
# Unemployed       219
# Name: count, dtype: int64

# %% [markdown]
# Check for colinearity

# %%
trainX = data.drop(columns=["vulnerable"])

# %%
data["vulnerable"].value_counts()
# need to normalise the data to have equal numbers of TRUE and FALSE
# Out:
# vulnerable
# 1    647
# 0    353
# Name: count, dtype: int64

# %%
X = trainX
y = data.vulnerable

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=123
)

clf = make_pipeline(StandardScaler(), LinearSVC(dual="auto", random_state=0, tol=1e-5))
models, predictions = clf.fit(
    X_train,
    y_train,
)

print(models)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8540\498514815.py in ?()
#       5     X, y, test_size=0.5, random_state=123
#       6 )
#       7
#       8 clf = make_pipeline(StandardScaler(), LinearSVC(dual="auto", random_state=0, tol=1e-5))
# ----> 9 models, predictions = clf.fit(
#      10     X_train,
#      11     y_train,
#      12 )
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\pipeline.py in ?(self, X, y, **params)
#     465         self : object
#     466             Pipeline with fitted steps.
#     467         """
#     468         routed_params = self._check_method_params(method="fit", props=params)
# --> 469         Xt = self._fit(X, y, routed_params)
#     470         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     471             if self._final_estimator != "passthrough":
#     472                 last_step_params = routed_params[self.steps[-1][0]]
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\pipeline.py in ?(self, X, y, routed_params)
#     402                 cloned_transformer = transformer
#     403             else:
#     404                 cloned_transformer = clone(transformer)
#     405             # Fit or load from cache the current transformer
# --> 406             X, fitted_transformer = fit_transform_one_cached(
#     407                 cloned_transformer,
#     408                 X,
#     409                 y,
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\joblib\memory.py in ?(self, *args, **kwargs)
#     311     def __call__(self, *args, **kwargs):
# --> 312         return self.func(*args, **kwargs)
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, message_clsname, message, params)
#    1306     """
#    1307     params = params or {}
#    1308     with _print_elapsed_time(message_clsname, message):
#    1309         if hasattr(transformer, "fit_transform"):
# -> 1310             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311         else:
#    1312             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313                 X, **params.get("transform", {})
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1097             # fit method of arity 1 (unsupervised transformation)
#    1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
# -> 1101             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# c:\Users\leahs\wit_hackathon\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'e830aa0e-028f-4526-b2cd-35930881d094'
